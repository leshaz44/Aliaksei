# %% [markdown]
# <a href="https://colab.research.google.com/github/leshaz44/My_rep_1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22My_9_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Напишите функцию, которая принимает строку и возвращает True, если строка является палиндромом (игнорируя регистр и пробелы), и False в противном случае.

# %% [markdown]
# Напишите функцию, которая принимает строку и возвращает True, если строка является палиндромом (игнорируя регистр и пробелы), и False в противном случае.

# %%
def palind(s_pal: str) -> bool: # создаю функцию, обявляю ее аргумент и результат выполнения будет bool
    s_pal = input("Введите текст:")
    #s = s_pal.lower()
    #return
    #print(s_palind)
    #palind()
    print(f"Результат, {s_pal}")
    #palind()
